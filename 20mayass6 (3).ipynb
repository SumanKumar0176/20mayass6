# %%
Q.1. What are keywords in python? Using the keyword library, print all the python keywords.
Ans:
In Python, keywords are reserved words that have special meanings and purposes within the language. 
These keywords cannot be used as variable names or identifiers because they are already predefined 
and serve specific functions in Python's syntax and structure.

import keyword

all_keywords = keyword.kwlist
print(all_keywords)

# %%
Q.2. What are the rules to create variables in python?
Ans:

In Python, variables are used to store and manipulate data. Here are the rules to create variables in Python:

i.Variable Names:

Variable names must start with a letter (a-z, A-Z) or an underscore (_). It cannot start with a number.
The rest of the variable name can consist of letters, numbers, and underscores.
Variable names are case-sensitive, meaning myVariable and myvariable are different variables.

ii.Reserved Keywords:

You cannot use reserved keywords as variable names since they have special meanings in Python. Examples of reserved 
keywords include if, for, while, def, class, import, and so on. You can refer to the previous question to print all
 the Python keywords using the keyword library.
Valid Examples:

Valid variable names: my_var, count, _data, result123, Name
Invalid variable names: 123var (starts with a number), for (reserved keyword), my-variable (contains a hyphen)

iii.Best Practices:

Choose descriptive variable names that convey the meaning of the data they store.
Use lowercase letters for variable names (e.g., my_variable) to follow the recommended Python naming convention.
If a variable name contains multiple words, you can use underscores (_) or follow the "camelCase" convention
 (e.g., my_variable or myVariable)

# %%
Q.3. What are the standards and conventions followed for the nomenclature of variables in
python to improve code readability and maintainability?
Ans:
In Python, there are widely accepted standards and conventions for naming variables to improve code readability and maintainability.
 These conventions help make your code more consistent and understandable, especially when collaborating with others. Here are some common practices:
i.Use Descriptive Names:
ii.Lowercase with Underscores (Snake Case): 
iii.Avoid Single-letter Names: 
iv.Constants in Uppercase:
v.Class Names in CamelCase:
vi.Module-level Variables:
vii.Avoid Shadowing
viii.Meaningful Function and Method Names:

# %%
Q.4. What will happen if a keyword is used as a variable name?
Ans:
If a keyword is used as a variable name in Python, it will result in a syntax error. Python keywords are 
reserved words that have predefined meanings and purposes within the language. They are used to define the syntax and structure of the code.




Q.5. For what purpose def keyword is used?
Ans:
In Python, the def keyword is used to define a function. Functions are blocks of reusable code that perform a specific task when called. The def keyword 
is followed by the name of the function, a set of parentheses, and a colon. Any code inside the function is indented under the def statement.
def greet():
    print("Hello, world!")

# Calling the function
greet()

# %%
Q.6. What is the operation of this special character ‘\’?
Ans:

The special character \ in Python is known as the backslash. It is used as an escape character or to create special character 
sequences within strings or other literals. Here are some common uses and operations of the backslash:

i.Escape Sequences: The backslash is used to escape certain characters that have special meanings in strings. For example:

\' - represents a single quote within a string.
\" - represents a double quote within a string.
\\ - represents a literal backslash within a string.
\n - represents a newline character.
\t - represents a tab character.
\r - represents a carriage return character.
ii.Unicode Escape Sequences: The backslash is used to represent Unicode characters using their hexadecimal representation. For example,
 \uXXXX represents a Unicode character in the Basic Multilingual Plane (BMP), and \UXXXXXXXX represents a Unicode character outside the BMP.

iii.Line Continuation: The backslash can be used to split long lines of code into multiple lines for improved readability. By placing a
 backslash at the end of a line, the code continues on the next line. For example:

python
Copy code
long_string = "This is a very long string that \
can be split into multiple lines."
iv.Regular Expressions: The backslash is used to escape special characters in regular expressions. It indicates that the next character 
should be treated as a literal character rather than having special meaning.

File Paths: In file paths on Windows systems, the backslash is used as a directory separator. For example, C:\path\to\file.txt.

# %%
Q.7. Give an example of the following conditions:
(i) Homogeneous list
(ii) Heterogeneous set
(iii) Homogeneous tuple
Ans:
(i) Homogeneous list:
A homogeneous list is a list in which all the elements have the same data type. Here's an example of a homogeneous list containing integers:
numbers = [1, 2, 3, 4, 5]


(ii) Heterogeneous set:
A heterogeneous set is a set in which the elements can have different data types. Here's an example of a heterogeneous set:
my_set = {1, 'hello', 3.14, True}

(iii) Homogeneous tuple:
A homogeneous tuple is a tuple in which all the elements have the same data type. Here's an example of a homogeneous tuple containing strings:
fruits = ('apple', 'banana', 'orange', 'grape')

# %%
Q.8. Explain the mutable and immutable data types with proper explanation & examples.
Ans:

Mutable Data Types:
Mutable data types are those that can be modified after creation. This means you can change the value of an individual element within the data type without creating a new object.
Examples of mutable data types in Python include lists, sets, and dictionaries.
Here's an example illustrating the mutability of a list:
my_list = [1, 2, 3]
print(my_list)  # Output: [1, 2, 3]

my_list[1] = 5
print(my_list)  # Output: [1, 5, 3]

Immutable Data Types:
Immutable data types, on the other hand, cannot be changed once they are created. If you want to modify the value, you need to create a new object with the updated value.
Examples of immutable data types in Python include integers, floats, strings, and tuples.
Here's an example illustrating the immutability of a string:
my_string = "Hello"
print(my_string)  # Output: Hello

my_string += " World"
print(my_string)  # Output: Hello World

# %%
Q.9. Write a code to create the given structure using only for loop.
   *
  ***
 *****
*******

Ans:
num_rows = 4
for i in range(num_rows):
    for j in range(num_rows - i - 1):
        print(" ", end="")
    for k in range(2*i + 1):
        print("*", end="")
    print()

# %%
Q.10. Write a code to create the given structure using while loop.
|||||||||
 |||||||
  |||||
   |||
    |

Ans:
num_rows = 5
row = 0
while row < num_rows:
    col = 0
    while col < row:
        print(" ", end="")
        col += 1
    col = 0
    while col < (2 * (num_rows - row) - 1):
        print("|", end="")
        col += 1
    print()
    row += 1
